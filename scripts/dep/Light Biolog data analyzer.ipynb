# %%
import os
from openpyxl import load_workbook
import re
import numpy as np
import pandas as pd

# %% [markdown]
# **import os**
#
# this imports Python's built-in os (operating system) module and gives your code access to functions that interact with the host computer's operating system.
#
# **from openpyxl import load_workbook**
#
# openpyxl is a Python library designed for reading and for writing Excel files. This provides a robust and efficient way to interact with Excel spreadsheets programmatically. The load_workbook function within openpyxl is a crucial component for working with existing Excel files. It's primary purpose is to load an Excel workbook from a specified file path and return a Workbook object, which represents the entire Excel file in Python.
#
# **import re**
#
# this imports Python's built-in regular expression module and lets you search for complex patterns in strings (e.g., emails, phone numbers). Examples are re.search() - finds a pattern in text, re.findall() - finds all matching parts, re.sub() - replaces parts of strings.
#
# **import numpy as np**
#
# imports the numpy library and gives it the nickname np. numpy is a powerful library for fast mathematical operations on arrays and matrices. It is essential for data science, numerical computing, and working with large datasets.
#
# **import pandas as pd**
#
# this imports pandas library as pd, pandas is used for handling structured data, like Excel files, CSVs etc. and provides two key data structures: Series - a one demensional labeled array and DataFrame: a two-demensional table (like a spreadsheet)

# %%
print(os.getcwd()) #used to see what directory I am currently in
# Out:
# C:\Users\Barba\Desktop

# %%
# in case I need to change the working directory use this
#os.chdir('/Users/Barba/Desktop')

# %%
excel_file = pd.ExcelFile('C:/Users/Barba/Desktop/RawBlog_20250125.xlsx') 
# this line of code loads an existing Excel file into Pythono using pandas and creates an ExcelFile
# object and assigns it to the varible excel_file

# %%
print(excel_file.sheet_names)
# this line of code prints a list of all the sheet names in the Excel file that was loaded
# this is mostly for me to view the sheet names
# Out:
# ['T7 P4 N', 'T7 P3 N', 'T7 P2 N', 'T7 P1 N', 'T7 P4 C2', 'T7 P3 C2', 'T7 P2 C2', 'T7 P1 C2', 'T7 P4 C1', 'T7 P3 C1', 'T7 P2 C1', 'T7 P1 C1', 'T6 P4 N', 'T6 P3 N', 'T6 P2 N', 'T6 P1 N', 'T6 P4 C2', 'T6 P3 C2', 'T6 P2 C2', 'T6 P1 C2', 'T6 P4 C1', 'T6 P3 C1', 'T6 P2 C1', 'T6 P1 C1', 'T5 P4 N', 'T5 P3 N', 'T5 P2 N', 'T5 P1 N', 'T5 P4 C2', 'T5 P3 C2', 'T5 P2 C2', 'T5 P1 C2', 'T5 P4 C1', 'T5 P3 C1', 'T5 P2 C1', 'T5 P1 C1', 'T4 P4 N', 'T4 P3 N', 'T4 P2 N', 'T4 P1 N', 'T4 P4 C2', 'T4 P3 C2', 'T4 P2 C2', 'T4 P1 C2', 'T4 P4 C1', 'T4 P3 C1', 'T4 P2 C1', 'T4 P1 C1', 'T3 P4 N', 'T3 P3 N', 'T3 P2 N', 'T3 P1 N', 'T3 P4 C2', 'T3 P3 C2', 'T3 P2 C2', 'T3 P1 C2', 'T3 P4 C1', 'T3 P3 C1', 'T3 P2 C1', 'T3 P1 C1', 'T2 P4 N', 'T2 P3 N', 'T2 P2 N', 'T2 P1 N', 'T2 P4 C2', 'T2 P3 C2', 'T2 P2 C2', 'T2 P1 C2', 'T2 P4 C1', 'T2 P2 C1', 'T2 P1 C1', 'T2 P3 C1', 'T1 P4 N', 'T1 P3 N', 'T1 P2 N', 'T1 P1 N', 'T1 P4 C2', 'T1 P3 C2', 'T1 P2 C2', 'T1 P1 C2', 'T1 P3 C1', 'T1 P2 C1', 'T1 P1 C1', 'T1 P4 C1', 'T0 P4 C1', 'T0 P3 C1', 'T0 P2 C1', 'T0 P1 C1', 'T0 P4 C2', 'T0 P3 C2', 'T0 P2 C2', 'T0 P1 C2', 'T0 P4 N', 'T0 P3 N', 'T0 P2 N', 'T0 P1 N']

# %%
condition_sheets = {'C1': [], 'C2': [], 'N': []}
# creation of the dictionary called condition_sheets with three keys C1, C2, and N.
# each key is assigned an empty list.

# %%
for sheet in excel_file.sheet_names:
    parts = sheet.split()
    if len(parts) == 3:
        condition = parts[2]
        if condition in condition_sheets:
            condition_sheets[condition].append(sheet)

for condition, sheets in condition_sheets.items():
    output_path = f'C:/Users/Barba/Desktop/{condition}_combined.xlsx'
    with pd.ExcelWriter(output_path) as writer:
        for sheet in sheets:
            df = excel_file.parse(sheet)
            df.to_excel(writer, sheet_name=sheet, index=False)
        print(f"{condition} saved to {output_path}")
# Out:
# C1 saved to C:/Users/Barba/Desktop/C1_combined.xlsx
# C2 saved to C:/Users/Barba/Desktop/C2_combined.xlsx
# N saved to C:/Users/Barba/Desktop/N_combined.xlsx

# %% [markdown]
# **Here the code will group sheets by type (C1, C2, or N) and save each group into its own Excel file.**
#
# # This first loop will loop through every sheet name in the excel file.
# for sheet in excel_file.sheet_names:
#     parts = sheet.split() # Split the sheet name into parts using the spaces in the sheet name. .split() breaks a string into parts wherever there is a space.
#     if len(parts) == 3: # Only process sheets with exactly 3 parts in their name, this ensures the sheet names is in the expected format like "T0 P1 C1"
#         condition = parts[2] # Gets the third part within the sheet name, which in this case the third part represents the condition.
#         if condition in condition_sheets: # this line checks if the value of condition (like 'C1') is a key in that dictionary
#             condition_sheets[condition].append(sheet) # If the condition is one of the keys (the keys being C1, C2, N) in condition_sheets, add that sheet to the corresponding list.
#
# # Here I am saving the grouped sheets to new files
# for condition, sheets in condition_sheets.items(): # this loops through each condition (C1, C2, N) and their associated sheet names
#     output_path = f'C:/Users/Barba/Desktop/{condition}_combined.xlsx' # This creates the full file path for the output Excel file it does not create the file yet. The f before the string is an f-string, which allows you to insert variables like this: {condition}.
#     with pd.ExcelWriter(output_path) as writer: # pd.ExcelWriter(...) opens a tool that lets you write to a new file Excel file (this is creating the new file as well). The with statement ensures the file is properly saved and closed afterward (even if an error happens).
#         for sheet in sheets: # This loops over all the sheet names you grouped under the current condition (whether that is C1, C2, or N).
#             df = excel_file.parse(sheet) # excel_file is the object that opened the original Excel file. .parse(sheet) means read the data from the Excel sheet and converts it into a DataFrame. Take the data from this one sheet in the original Excel file, and store it in df as a table (DataFrame)
#             df.to_excel(writer, sheet_name=sheet, index=False) # This writes the df (the table) to the new Excel file and will keep the same sheet_name as the original on e it came from. index=False tells pandas not to include the row numbers (index) in the saved file.
#         print(f"{condition} saved to {output_path}")

# %% [markdown]
# # Create separate files for 680-only data
# for condition, sheets in condition_sheets.items():
#     output_path = f'C:/Users/Barba/Desktop/{condition}_680_only.xlsx'
#
#     # Initialize plate data containers
#     plate_data = {'P1': {}, 'P2': {}, 'P3': {}, 'P4': {}}
#
#     for sheet in sheets:
#         parts = sheet.split()
#         if len(parts) != 3:
#             continue
#
#         time, plate, cond = parts
#
#         # Validate timepoint format and plate
#         if not time.startswith('T') or plate not in plate_data:
#             continue
#
#         df = excel_file.parse(sheet)
#
#         if 680 not in df.columns:
#             print(f"⚠️ Skipping sheet '{sheet}' — no 680 column found.")
#             continue
#
#         # Extract and rename the 680 column
#         timepoint_column = df[[680]].rename(columns={680: time})
#         plate_data[plate][time] = timepoint_column
#
#     # Save all 680-only data for this condition in a new file
#     with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
#         for plate, time_dict in plate_data.items():
#             if not time_dict:
#                 print(f"⚠️ No 680 data found for {plate} in {condition}")
#                 continue
#
#             # Sort timepoints numerically
#             sorted_times = sorted(time_dict.keys(), key=lambda t: int(t[1:]))
#
#             # Concatenate 680 columns
#             merged_df = pd.concat([time_dict[t] for t in sorted_times], axis=1)
#
#             sheet_name = f"{plate}_680"
#             merged_df.to_excel(writer, sheet_name=sheet_name, index=False)
#             print(f"✅ Created sheet '{sheet_name}' in {output_path}")

# %%
# correct for volume
conditions = ['C1', 'C2', 'N'] #list of files to process

for condition in conditions:  # added a loop to process each file
    file_path = f'C:/Users/Barba/Desktop/{condition}_combined.xlsx'
    excel_file = pd.ExcelFile(file_path, engine='openpyxl')
    volume_data = pd.DataFrame()
    
    for sheet in excel_file.sheet_names:
        parts = sheet.split()
        if len(parts) != 3:
            continue
        time, plate, sheet_condition = parts
        df = excel_file.parse(sheet)
        df.columns = df.columns.astype(str).str.strip()
        if '980' in df.columns and '900' in df.columns:
            df['Volume'] = (df['980'] - df['900'])/ 0.0010018
            col_name = f'{time} {plate} {condition}'
            volume_data[col_name] = df['Volume']
    if not volume_data.empty:
        with pd.ExcelWriter(file_path, mode='a', engine='openpyxl', if_sheet_exists='replace') as writer:
            volume_data.to_excel(writer, sheet_name=f'{condition}_volume_data', index=False)
        print(f"Volume data added to {file_path}")
        
        wb = load_workbook(file_path)
        wb.save(file_path)
        print(f"Workbook saved explicitly at {file_path}")
    
        excel_file = pd.ExcelFile(file_path)
        print(f"Sheets available in the workbook after saving: {excel_file.sheet_names}")
    
    else:
        print("No volume data was added. Check column names or sheet format.")
# Out:
# Volume data added to C:/Users/Barba/Desktop/C1_combined.xlsx
# Workbook saved explicitly at C:/Users/Barba/Desktop/C1_combined.xlsx
# Sheets available in the workbook after saving: ['T7 P4 C1', 'T7 P3 C1', 'T7 P2 C1', 'T7 P1 C1', 'T6 P4 C1', 'T6 P3 C1', 'T6 P2 C1', 'T6 P1 C1', 'T5 P4 C1', 'T5 P3 C1', 'T5 P2 C1', 'T5 P1 C1', 'T4 P4 C1', 'T4 P3 C1', 'T4 P2 C1', 'T4 P1 C1', 'T3 P4 C1', 'T3 P3 C1', 'T3 P2 C1', 'T3 P1 C1', 'T2 P4 C1', 'T2 P2 C1', 'T2 P1 C1', 'T2 P3 C1', 'T1 P3 C1', 'T1 P2 C1', 'T1 P1 C1', 'T1 P4 C1', 'T0 P4 C1', 'T0 P3 C1', 'T0 P2 C1', 'T0 P1 C1', 'C1_volume_data']
# Volume data added to C:/Users/Barba/Desktop/C2_combined.xlsx
# Workbook saved explicitly at C:/Users/Barba/Desktop/C2_combined.xlsx
# Sheets available in the workbook after saving: ['T7 P4 C2', 'T7 P3 C2', 'T7 P2 C2', 'T7 P1 C2', 'T6 P4 C2', 'T6 P3 C2', 'T6 P2 C2', 'T6 P1 C2', 'T5 P4 C2', 'T5 P3 C2', 'T5 P2 C2', 'T5 P1 C2', 'T4 P4 C2', 'T4 P3 C2', 'T4 P2 C2', 'T4 P1 C2', 'T3 P4 C2', 'T3 P3 C2', 'T3 P2 C2', 'T3 P1 C2', 'T2 P4 C2', 'T2 P3 C2', 'T2 P2 C2', 'T2 P1 C2', 'T1 P4 C2', 'T1 P3 C2', 'T1 P2 C2', 'T1 P1 C2', 'T0 P4 C2', 'T0 P3 C2', 'T0 P2 C2', 'T0 P1 C2', 'C2_volume_data']
# Volume data added to C:/Users/Barba/Desktop/N_combined.xlsx
# Workbook saved explicitly at C:/Users/Barba/Desktop/N_combined.xlsx
# Sheets available in the workbook after saving: ['T7 P4 N', 'T7 P3 N', 'T7 P2 N', 'T7 P1 N', 'T6 P4 N', 'T6 P3 N', 'T6 P2 N', 'T6 P1 N', 'T5 P4 N', 'T5 P3 N', 'T5 P2 N', 'T5 P1 N', 'T4 P4 N', 'T4 P3 N', 'T4 P2 N', 'T4 P1 N', 'T3 P4 N', 'T3 P3 N', 'T3 P2 N', 'T3 P1 N', 'T2 P4 N', 'T2 P3 N', 'T2 P2 N', 'T2 P1 N', 'T1 P4 N', 'T1 P3 N', 'T1 P2 N', 'T1 P1 N', 'T0 P4 N', 'T0 P3 N', 'T0 P2 N', 'T0 P1 N', 'N_volume_data']

# %% [markdown]
# # correct for volume
# conditions = ['C1', 'C2', 'N'] # this is a list of strings, these were created earlier by grouping the sheets. These strings C1, C2, and N match the file names C1_combined.xlsx, etc.
#
# for condition in conditions:  # added a loop to process each file # This outer for loop loops through each of the conditions (C1, C2, N). For each condition the code will open the file, process its sheets, calculate volume and add a new sheet with the new volume data.
#     file_path = f'C:/Users/Barba/Desktop/{condition}_combined.xlsx' # Creates a file path using the current condition in the loop.
#     excel_file = pd.ExcelFile(file_path, engine='openpyxl') # This opens the Excel file created earlier (C1_combined.xlsx) at file_path using pandas. engine='openpyxl' tells pandas which library to use to read the .xlsx file.
#     volume_data = pd.DataFrame() # Creates an empty DataFrame to hold the new volume results.
#
#     for sheet in excel_file.sheet_names: # This inner loop loops through each sheet inside the current Excel file.
#         parts = sheet.split() # This splits the sheet name into parts
#         if len(parts) != 3:
#             continue # This skips the sheet if its name doesn't split into exactly 3 words.
#         time, plate, sheet_condition = parts # This assigns each part of the sheet name to a variable: time=T0, plate=P1, sheet_condition=C1. Used sheet_condition (not just condition) to avoid naming conflicts with the outer loop.
#         df = excel_file.parse(sheet) # This reads the current sheet's data into a DataFrame (df)
#         df.columns = df.columns.astype(str).str.strip() # This makes sure all column names are strings and removes any spaces
#         if '980' in df.columns and '900' in df.columns: # Volume calculation, only calculate if both required columns '980' and '900' are present.
#             df['Volume'] = (df['980'] - df['900'])/ 0.0010018 # This calculates a volume column using the difference between columns '980' and '900'
#             col_name = f'{time} {plate} {condition}' # This creates a name like 'T0, P1, C1' for this column
#             volume_data[col_name] = df['Volume'] #
#     if not volume_data.empty: # This checks if volume_data is empty or not.
#         with pd.ExcelWriter(file_path, mode='a', engine='openpyxl', if_sheet_exists='replace') as writer: # with pd.ExcelWriter(...) as writer: opens the existing Excel file for writing. mode='a':append and don't overwrite the file. if_sheet_exists='replace': if a sheet with the same name exists, replace it
#             volume_data.to_excel(writer, sheet_name=f'{condition}_volume_data', index=False) # This saves the volume data as a new sheet (like "C1_volume_data") index=False: don't include pandas' default row numbers in the saved sheet
#         print(f"Volume data added to {file_path}")
#
#         wb = load_workbook(file_path)
#         wb.save(file_path) # Sometimes changes made by pandas don’t fully register in Excel. This opens the file again with openpyxl and saves it manually — just to be sure it’s really saved.
#         print(f"Workbook saved explicitly at {file_path}")
#
#         excel_file = pd.ExcelFile(file_path)
#         print(f"Sheets available in the workbook after saving: {excel_file.sheet_names}")
#         # Re-opens the file again and prints out all the sheet names in the file — lets you see if the new volume sheet was actually added.
#
#     else:
#         print("No volume data was added. Check column names or sheet format.")
#         # If the volume_data DataFrame is still empty, it means: Maybe the sheets didn’t have '980' and '900'. Or the sheet names were not in the expected format. So it prints a warning so you know to investigate

# %%
# Pathlength for all three files based on volume data

conditions = ['C1', 'C2', 'N']

for condition in conditions:
    file_path = f'C:/Users/Barba/Desktop/{condition}_combined.xlsx'
    excel_file = pd.ExcelFile(file_path, engine='openpyxl')

    volume_sheet_name = f'{condition}_volume_data'
    if volume_sheet_name in excel_file.sheet_names:
        volume_df = excel_file.parse(volume_sheet_name)
        pathlength_df = (0.0055 * volume_df) + 0.0128
        pathlength_df.columns = volume_df.columns
    
        with pd.ExcelWriter(file_path, mode='a', engine='openpyxl', if_sheet_exists='replace') as writer:
            pathlength_df.to_excel(writer, sheet_name=f'{condition}_pathlength_data', index=False)
        print(f"Path length data added to {file_path}")
    
        wb = load_workbook(file_path)
        wb.save(file_path)
        print(f"Workbook saved explicitly at {file_path}")
    
        excel_file = pd.ExcelFile(file_path)
        print(f"Sheets available in the workbook after saving: {excel_file.sheet_names}")
    
    else:
        print(f"Volume sheet '{volume_sheet_name}' not found. Cannot calculate path length.")
# Out:
# Path length data added to C:/Users/Barba/Desktop/C1_combined.xlsx
# Workbook saved explicitly at C:/Users/Barba/Desktop/C1_combined.xlsx
# Sheets available in the workbook after saving: ['T7 P4 C1', 'T7 P3 C1', 'T7 P2 C1', 'T7 P1 C1', 'T6 P4 C1', 'T6 P3 C1', 'T6 P2 C1', 'T6 P1 C1', 'T5 P4 C1', 'T5 P3 C1', 'T5 P2 C1', 'T5 P1 C1', 'T4 P4 C1', 'T4 P3 C1', 'T4 P2 C1', 'T4 P1 C1', 'T3 P4 C1', 'T3 P3 C1', 'T3 P2 C1', 'T3 P1 C1', 'T2 P4 C1', 'T2 P2 C1', 'T2 P1 C1', 'T2 P3 C1', 'T1 P3 C1', 'T1 P2 C1', 'T1 P1 C1', 'T1 P4 C1', 'T0 P4 C1', 'T0 P3 C1', 'T0 P2 C1', 'T0 P1 C1', 'C1_volume_data', 'C1_pathlength_data']
# Path length data added to C:/Users/Barba/Desktop/C2_combined.xlsx
# Workbook saved explicitly at C:/Users/Barba/Desktop/C2_combined.xlsx
# Sheets available in the workbook after saving: ['T7 P4 C2', 'T7 P3 C2', 'T7 P2 C2', 'T7 P1 C2', 'T6 P4 C2', 'T6 P3 C2', 'T6 P2 C2', 'T6 P1 C2', 'T5 P4 C2', 'T5 P3 C2', 'T5 P2 C2', 'T5 P1 C2', 'T4 P4 C2', 'T4 P3 C2', 'T4 P2 C2', 'T4 P1 C2', 'T3 P4 C2', 'T3 P3 C2', 'T3 P2 C2', 'T3 P1 C2', 'T2 P4 C2', 'T2 P3 C2', 'T2 P2 C2', 'T2 P1 C2', 'T1 P4 C2', 'T1 P3 C2', 'T1 P2 C2', 'T1 P1 C2', 'T0 P4 C2', 'T0 P3 C2', 'T0 P2 C2', 'T0 P1 C2', 'C2_volume_data', 'C2_pathlength_data']
# Path length data added to C:/Users/Barba/Desktop/N_combined.xlsx
# Workbook saved explicitly at C:/Users/Barba/Desktop/N_combined.xlsx
# Sheets available in the workbook after saving: ['T7 P4 N', 'T7 P3 N', 'T7 P2 N', 'T7 P1 N', 'T6 P4 N', 'T6 P3 N', 'T6 P2 N', 'T6 P1 N', 'T5 P4 N', 'T5 P3 N', 'T5 P2 N', 'T5 P1 N', 'T4 P4 N', 'T4 P3 N', 'T4 P2 N', 'T4 P1 N', 'T3 P4 N', 'T3 P3 N', 'T3 P2 N', 'T3 P1 N', 'T2 P4 N', 'T2 P3 N', 'T2 P2 N', 'T2 P1 N', 'T1 P4 N', 'T1 P3 N', 'T1 P2 N', 'T1 P1 N', 'T0 P4 N', 'T0 P3 N', 'T0 P2 N', 'T0 P1 N', 'N_volume_data', 'N_pathlength_data']

# %%
# Here we calculate the correct OD with the calculated pathlength

conditions = ['C1', 'C2', 'N']
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")

for condition in conditions:
    file_path = os.path.join(desktop_path, f"{condition}_combined.xlsx")

    if not os.path.exists(file_path):
        print(f"File {file_path} not found. Skipping.")
        continue

    excel_file = pd.ExcelFile(file_path, engine='openpyxl')

    pathlength_sheet = f'{condition}_pathlength_data'
    if pathlength_sheet not in excel_file.sheet_names:
        print(f"Pathlength sheet '{pathlength_sheet}' not found. Skipping {condition}.")
        continue

    pathlength_df = excel_file.parse(pathlength_sheet)
    pathlength_df.columns = pathlength_df.columns.astype(str).str.strip()

    corrected_od_df = pd.DataFrame()

    for sheet in excel_file.sheet_names:
        parts = sheet.strip().split()
        if len(parts) != 3:
            continue

        time, plate, sheet_condition = parts
        if sheet_condition != condition:
            continue

        df = excel_file.parse(sheet)
        df.columns = df.columns.astype(str).str.strip()

        if '680' not in df.columns or 'Wavel.' not in df.columns:
            print(f"Skipping {sheet} - missing required columns.")
            continue

        df = df[df['Wavel.'].astype(str).str.match(r'^[A-H][1-9][0-2]?$')]
        df.reset_index(drop=True, inplace=True)

        pathlength_col = f"{time} {plate} {condition}"
        if pathlength_col not in pathlength_df.columns:
            print(f"Pathlength column '{pathlength_col}' not found. Skipping {sheet}.")
            continue

        pathlength_values = pathlength_df[pathlength_col]

        if len(pathlength_values) != len(df):
            print(f"Row mismatch in {sheet}. Skipping.")
            continue

        corrected_od = df['680'] / pathlength_values
        corrected_od_df[pathlength_col] = corrected_od

        print(f"Processed {sheet}")

    if not corrected_od_df.empty:
        with pd.ExcelWriter(file_path, mode='a', engine='openpyxl', if_sheet_exists='replace') as writer:
            corrected_od_df.to_excel(writer, sheet_name=f"{condition}_corrected_OD", index=False)
        print(f"Corrected OD saved to {file_path}")
    else:
        print(f"No corrected OD data saved for {condition}")
# Out:
# Processed T7 P4 C1
# Processed T7 P3 C1
# Processed T7 P2 C1
# Processed T7 P1 C1
# Processed T6 P4 C1
# Processed T6 P3 C1
# Processed T6 P2 C1
# Processed T6 P1 C1
# Processed T5 P4 C1
# Processed T5 P3 C1
# Processed T5 P2 C1
# Processed T5 P1 C1
# Processed T4 P4 C1
# Processed T4 P3 C1
# Processed T4 P2 C1
# Processed T4 P1 C1
# Processed T3 P4 C1
# Processed T3 P3 C1
# Processed T3 P2 C1
# Processed T3 P1 C1
# Processed T2 P4 C1
# Processed T2 P2 C1
# Processed T2 P1 C1
# Processed T2 P3 C1
# Processed T1 P3 C1
# Processed T1 P2 C1
# Processed T1 P1 C1
# Processed T1 P4 C1
# Processed T0 P4 C1
# Processed T0 P3 C1
# Processed T0 P2 C1
# Processed T0 P1 C1
# Corrected OD saved to C:\Users\Barba\Desktop\C1_combined.xlsx
# Processed T7 P4 C2
# Processed T7 P3 C2
# Processed T7 P2 C2
# Processed T7 P1 C2
# Processed T6 P4 C2
# Processed T6 P3 C2
# Processed T6 P2 C2
# Processed T6 P1 C2
# Processed T5 P4 C2
# Processed T5 P3 C2
# Processed T5 P2 C2
# Processed T5 P1 C2
# Processed T4 P4 C2
# Processed T4 P3 C2
# Processed T4 P2 C2
# Processed T4 P1 C2
# Processed T3 P4 C2
# Processed T3 P3 C2
# Processed T3 P2 C2
# Processed T3 P1 C2
# Processed T2 P4 C2
# Processed T2 P3 C2
# Processed T2 P2 C2
# Processed T2 P1 C2
# Processed T1 P4 C2
# Processed T1 P3 C2
# Processed T1 P2 C2
# Processed T1 P1 C2
# Processed T0 P4 C2
# Processed T0 P3 C2
# Processed T0 P2 C2
# Processed T0 P1 C2
# Corrected OD saved to C:\Users\Barba\Desktop\C2_combined.xlsx
# Processed T7 P4 N
# Processed T7 P3 N
# Processed T7 P2 N
# Processed T7 P1 N
# Processed T6 P4 N
# Processed T6 P3 N
# Processed T6 P2 N
# Processed T6 P1 N
# Processed T5 P4 N
# Processed T5 P3 N
# Processed T5 P2 N
# Processed T5 P1 N
# Processed T4 P4 N
# Processed T4 P3 N
# Processed T4 P2 N
# Processed T4 P1 N
# Processed T3 P4 N
# Processed T3 P3 N
# Processed T3 P2 N
# Processed T3 P1 N
# Processed T2 P4 N
# Processed T2 P3 N
# Processed T2 P2 N
# Processed T2 P1 N
# Processed T1 P4 N
# Processed T1 P3 N
# Processed T1 P2 N
# Processed T1 P1 N
# Processed T0 P4 N
# Processed T0 P3 N
# Processed T0 P2 N
# Processed T0 P1 N
# Corrected OD saved to C:\Users\Barba\Desktop\N_combined.xlsx

# %%
# separate corrected OD
import pandas as pd
import os
import re

# Define condition list and plate identifiers
conditions = ['C1', 'C2', 'N']
plates = ['P1', 'P2', 'P3', 'P4']
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")

for condition in conditions:
    file_path = os.path.join(desktop_path, f"{condition}_combined.xlsx")

    if not os.path.exists(file_path):
        print(f"❌ File {file_path} not found. Skipping.")
        continue

    # Load the corrected OD data
    excel_file = pd.ExcelFile(file_path, engine='openpyxl')
    corrected_sheet_name = f"{condition}_corrected_OD"

    if corrected_sheet_name not in excel_file.sheet_names:
        print(f"❌ Sheet '{corrected_sheet_name}' not found in {file_path}. Skipping.")
        continue

    corrected_df = excel_file.parse(corrected_sheet_name)
    corrected_df.columns = corrected_df.columns.astype(str).str.strip()

    # Output Excel file path
    output_path = os.path.join(desktop_path, f"{condition}_correctOD.xlsx")

    with pd.ExcelWriter(output_path, engine='openpyxl') as writer:
        for plate in plates:
            # Filter and sort columns for this plate
            plate_cols = [col for col in corrected_df.columns if f"{plate} {condition}" in col]
            sorted_plate_cols = sorted(plate_cols, key=lambda x: int(re.search(r'T(\d+)', x).group(1)))

            if not sorted_plate_cols:
                print(f"⚠️ No columns found for {plate} in condition {condition}")
                continue

            plate_df = corrected_df[sorted_plate_cols]
            plate_df.to_excel(writer, sheet_name=plate, index=False)
            print(f"✅ Wrote sheet '{plate}' in {output_path}")

    print(f"✅ Finished writing: {output_path}")
# Out:
# ✅ Wrote sheet 'P1' in C:\Users\Barba\Desktop\C1_correctOD.xlsx
# ✅ Wrote sheet 'P2' in C:\Users\Barba\Desktop\C1_correctOD.xlsx
# ✅ Wrote sheet 'P3' in C:\Users\Barba\Desktop\C1_correctOD.xlsx
# ✅ Wrote sheet 'P4' in C:\Users\Barba\Desktop\C1_correctOD.xlsx
# ✅ Finished writing: C:\Users\Barba\Desktop\C1_correctOD.xlsx
# ✅ Wrote sheet 'P1' in C:\Users\Barba\Desktop\C2_correctOD.xlsx
# ✅ Wrote sheet 'P2' in C:\Users\Barba\Desktop\C2_correctOD.xlsx
# ✅ Wrote sheet 'P3' in C:\Users\Barba\Desktop\C2_correctOD.xlsx
# ✅ Wrote sheet 'P4' in C:\Users\Barba\Desktop\C2_correctOD.xlsx
# ✅ Finished writing: C:\Users\Barba\Desktop\C2_correctOD.xlsx
# ✅ Wrote sheet 'P1' in C:\Users\Barba\Desktop\N_correctOD.xlsx
# ✅ Wrote sheet 'P2' in C:\Users\Barba\Desktop\N_correctOD.xlsx
# ✅ Wrote sheet 'P3' in C:\Users\Barba\Desktop\N_correctOD.xlsx
# ✅ Wrote sheet 'P4' in C:\Users\Barba\Desktop\N_correctOD.xlsx
# ✅ Finished writing: C:\Users\Barba\Desktop\N_correctOD.xlsx

# %%
# finding natural log

conditions = ['C1', 'C2', 'N'] 
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")

for condition in conditions:
    file_path = os.path.join(desktop_path, f"{condition}_combined.xlsx")
    
    if not os.path.exists(file_path):
        print(f"File {file_path} not found. Skipping.")
        continue

    excel_file = pd.ExcelFile(file_path, engine='openpyxl')
    corrected_sheet = f"{condition}_corrected_OD"

    if corrected_sheet not in excel_file.sheet_names:
        print(f"Corrected OD sheet '{corrected_sheet}' not found. Skipping {condition}.")
        continue

    corrected_df = excel_file.parse(corrected_sheet)
    corrected_df.columns = corrected_df.columns.astype(str).str.strip()

    log_fc_df = pd.DataFrame()

    for col in corrected_df.columns:
        if not col.startswith("T0 "):
            continue  # We'll use T0 columns as baselines

        # Find all columns matching the same plate/condition
        _, plate, _ = col.split()
        matching_cols = [c for c in corrected_df.columns if c.endswith(f"{plate} {condition}")]
        
        baseline = corrected_df[col]
        if baseline.isna().any() or (baseline <= 0).any():
            print(f"Invalid baseline values in {col}. Skipping plate {plate}.")
            continue

        for mc in matching_cols:
            # Avoid dividing by T0 itself
            if mc == col:
                # Add T0 column directly (no log transformation)
                log_fc_df[mc] = baseline
                continue

            log_fc = np.log(corrected_df[mc] / baseline)
            log_fc = log_fc.apply(lambda x: x if x >= 0 else 0)
            log_fc_df[mc] = log_fc

    if not log_fc_df.empty:
        with pd.ExcelWriter(file_path, mode='a', engine='openpyxl', if_sheet_exists='replace') as writer:
            log_fc_df.to_excel(writer, sheet_name=f"{condition}_logFC_data", index=False)
        print(f" Log fold change saved to {file_path} in sheet '{condition}_logFC_data'")
    else:
        print(f"No valid log fold change data for {condition}")
# Out:
#  Log fold change saved to C:\Users\Barba\Desktop\C1_combined.xlsx in sheet 'C1_logFC_data'
#  Log fold change saved to C:\Users\Barba\Desktop\C2_combined.xlsx in sheet 'C2_logFC_data'
#  Log fold change saved to C:\Users\Barba\Desktop\N_combined.xlsx in sheet 'N_logFC_data'

# %%
# Separating data to use for gompertz model

conditions = ['C1', 'C2', 'N']
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")

for condition in conditions:
    file_path = os.path.join(desktop_path, f"{condition}_combined.xlsx")
    
    if not os.path.exists(file_path):
        print(f"File {file_path} not found. Skipping.")
        continue

    excel_file = pd.ExcelFile(file_path, engine='openpyxl')
    logfc_sheet = f"{condition}_logFC_data"

    if logfc_sheet not in excel_file.sheet_names:
        print(f"LogFC sheet '{logfc_sheet}' not found. Skipping {condition}.")
        continue

    logfc_df = excel_file.parse(logfc_sheet)
    logfc_df.columns = logfc_df.columns.astype(str).str.strip()

    # Get all unique plates (P1, P2, ...) for this condition
    plate_names = set()
    for col in logfc_df.columns:
        parts = col.split()
        if len(parts) == 3:
            _, plate, cond = parts
            if cond == condition:
                plate_names.add(plate)

    for plate in sorted(plate_names):
        # Filter columns for this plate and condition
        plate_cols = [col for col in logfc_df.columns if col.endswith(f"{plate} {condition}")]
        plate_df = logfc_df[plate_cols].copy()
        
        # Optional: rename columns to just timepoints (e.g., T0, T1, ...)
        new_col_names = [col.split()[0] for col in plate_cols]
        plate_df.columns = new_col_names

        # Print or store the extracted plate data
        print(f"\n Extracted data for {plate} under {condition}:")
        print(plate_df.head())

        # Optional: Save to new sheet
        with pd.ExcelWriter(file_path, mode='a', engine='openpyxl', if_sheet_exists='replace') as writer:
            sheet_name = f"{condition}_{plate}_logFC"
            plate_df.to_excel(writer, sheet_name=sheet_name, index=False)
        print(f" Saved to sheet '{sheet_name}' in {file_path}")
# Out:
#  Extracted data for P1 under C1:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  0.935904  0.864637  0.732143  0.621775  0.531874  0.442565  0.157605
# 1  1.151600  1.110453  0.995779  0.975800  1.313122  0.912310  0.191948
# 2  1.751655  1.681042  1.533475  1.458425  1.462764  0.987370  0.261107
# 3  1.564393  1.432634  1.298145  1.202160  1.185103  0.526150  0.212946
# 4  1.771773  1.641261  1.438565  1.314807  1.103197  1.024314  0.346302
#
#          T0
# 0  0.208153
# 1  0.198521
# 2  0.196281
# 3  0.196267
# 4  0.187672
#  Saved to sheet 'C1_P1_logFC' in C:\Users\Barba\Desktop\C1_combined.xlsx
#
#  Extracted data for P2 under C1:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  1.125057  1.051638  0.892121  0.815248  0.681628  0.596962  0.234797
# 1  1.345141  1.312635  1.222164  1.196236  1.300252  0.951825  0.201624
# 2  2.808702  2.707327  2.533089  2.344479  2.239928  1.279007  0.344168
# 3  1.692741  1.622532  1.382977  1.303534  1.019608  0.681173  0.285038
# 4  2.021494  1.790817  1.555981  1.506691  1.357637  1.261259  0.398528
#
#          T0
# 0  0.190509
# 1  0.190917
# 2  0.188076
# 3  0.184590
# 4  0.184840
#  Saved to sheet 'C1_P2_logFC' in C:\Users\Barba\Desktop\C1_combined.xlsx
#
#  Extracted data for P3 under C1:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  1.156903  1.090107  0.970929  0.889819  0.741097  0.627287  0.327757
# 1  2.432564  2.307392  2.152125  2.162878  2.037933  1.139507  0.336669
# 2  2.629078  2.508038  2.341332  2.209823  2.148987  1.098580  0.304054
# 3  1.875589  1.726104  1.606557  1.520697  1.501612  0.525898  0.249739
# 4  1.804090  1.608621  1.459479  1.435000  1.241116  1.157056  0.257003
#
#          T0
# 0  0.199450
# 1  0.182599
# 2  0.192284
# 3  0.197618
# 4  0.201170
#  Saved to sheet 'C1_P3_logFC' in C:\Users\Barba\Desktop\C1_combined.xlsx
#
#  Extracted data for P4 under C1:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  1.033822  0.955462  0.849618  0.766592  0.671409  0.571773  0.301267
# 1  1.204631  1.144181  1.075811  1.039631  0.965747  0.843049  0.289243
# 2  2.314546  2.144967  2.003155  1.864724  1.719766  1.070662  0.332253
# 3  1.690334  1.590761  1.431110  1.327149  1.125180  0.613796  0.546707
# 4  1.711250  1.618479  1.422684  1.258549  1.096150  1.035699  0.576782
#
#          T0
# 0  0.188810
# 1  0.191944
# 2  0.191189
# 3  0.186666
# 4  0.193420
#  Saved to sheet 'C1_P4_logFC' in C:\Users\Barba\Desktop\C1_combined.xlsx
#
#  Extracted data for P1 under C2:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  0.979314  0.926779  0.855758  0.786530  0.752566  0.678569  0.392424
# 1  0.742604  0.586048  0.504043  0.573724  0.388180  0.230353  0.098866
# 2  0.893225  0.708453  0.778466  0.588225  0.542482  0.497437  0.290352
# 3  1.094366  0.704113  0.540800  0.521024  0.478311  0.397563  0.159916
# 4  1.931107  1.237450  0.945523  0.801703  0.633493  0.514667  0.294504
#
#          T0
# 0  0.193906
# 1  0.232690
# 2  0.197280
# 3  0.226641
# 4  0.192482
#  Saved to sheet 'C2_P1_logFC' in C:\Users\Barba\Desktop\C2_combined.xlsx
#
#  Extracted data for P2 under C2:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  1.044196  0.848318  0.787936  0.714752  0.600532  0.499494  0.231444
# 1  1.039841  0.791414  0.702544  0.631610  0.532486  0.414672  0.157363
# 2  1.385297  0.908134  0.684965  0.540029  0.474243  0.407456  0.153999
# 3  1.179484  0.828287  0.627081  0.518933  0.444574  0.412445  0.223423
# 4  1.537241  1.217333  1.043013  0.914740  0.726527  0.614139  0.347436
#
#          T0
# 0  0.182433
# 1  0.188098
# 2  0.203655
# 3  0.202799
# 4  0.192055
#  Saved to sheet 'C2_P2_logFC' in C:\Users\Barba\Desktop\C2_combined.xlsx
#
#  Extracted data for P3 under C2:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  0.953311  0.860020  0.760572  0.687124  0.584511  0.512953  0.288344
# 1  0.940526  0.857571  0.784089  0.713968  0.606417  0.487285  0.265587
# 2  1.383687  0.847473  0.599826  0.504701  0.403744  0.345732  0.185126
# 3  1.232559  0.928438  0.728695  0.601334  0.548950  0.473008  0.290321
# 4  1.166265  0.919220  0.738663  0.629898  0.537499  0.468065  0.392505
#
#          T0
# 0  0.181078
# 1  0.176866
# 2  0.198815
# 3  0.201213
# 4  0.181056
#  Saved to sheet 'C2_P3_logFC' in C:\Users\Barba\Desktop\C2_combined.xlsx
#
#  Extracted data for P4 under C2:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  0.877394  0.799088  0.726974  0.646735  0.520639  0.446216  0.234702
# 1  0.824954  0.764479  0.688815  0.605030  0.513564  0.426048  0.198377
# 2  0.966776  0.678415  0.539532  0.458463  0.382063  0.397237  0.220524
# 3  1.161887  0.901480  0.721578  0.612258  0.512297  0.403016  0.228817
# 4  1.511970  1.005692  0.735485  0.602347  0.491960  0.429247  0.316783
#
#          T0
# 0  0.192967
# 1  0.185158
# 2  0.196099
# 3  0.205793
# 4  0.185458
#  Saved to sheet 'C2_P4_logFC' in C:\Users\Barba\Desktop\C2_combined.xlsx
#
#  Extracted data for P1 under N:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  0.796209  0.891025  1.238329  1.023765  0.824115  0.552821  0.445327
# 1  1.112116  1.106151  0.900728  0.600109  0.434589  0.415667  0.199883
# 2  0.504275  0.558301  0.621520  0.564628  0.394102  0.220230  0.107907
# 3  0.996588  1.016597  0.808164  0.672613  0.758595  0.572755  0.370997
# 4  0.870595  0.923639  0.711134  0.534421  0.862533  0.535618  0.348684
#
#          T0
# 0  0.201861
# 1  0.202846
# 2  0.204157
# 3  0.198030
# 4  0.196406
#  Saved to sheet 'N_P1_logFC' in C:\Users\Barba\Desktop\N_combined.xlsx
#
#  Extracted data for P2 under N:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  1.603327  1.540779  1.304947  0.890076  0.604610  0.340039  0.228631
# 1  1.132845  1.156318  1.165052  0.652048  0.405298  0.195302  0.067198
# 2  0.794208  0.881323  0.579226  0.494047  0.787731  0.449231  0.239460
# 3  1.053170  1.070923  1.026376  0.826964  0.537787  0.464710  0.154485
# 4  1.004118  1.031394  0.944841  0.742405  0.451922  0.217471  0.129262
#
#          T0
# 0  0.205050
# 1  0.202691
# 2  0.197090
# 3  0.199623
# 4  0.205544
#  Saved to sheet 'N_P2_logFC' in C:\Users\Barba\Desktop\N_combined.xlsx
#
#  Extracted data for P3 under N:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  1.587263  1.378498  1.142933  0.801311  0.456269  0.369921  0.217129
# 1  0.914792  0.911064  1.062488  0.705512  0.493812  0.379396  0.160028
# 2  0.607979  0.670464  0.569979  0.490399  0.234877  0.241336  0.147434
# 3  1.020648  1.042688  0.969530  0.712268  0.613964  0.501014  0.331086
# 4  0.745943  0.794627  0.852808  0.679631  0.535433  0.453989  0.282941
#
#          T0
# 0  0.211183
# 1  0.206985
# 2  0.197788
# 3  0.204067
# 4  0.196004
#  Saved to sheet 'N_P3_logFC' in C:\Users\Barba\Desktop\N_combined.xlsx
#
#  Extracted data for P4 under N:
#          T7        T6        T5        T4        T3        T2        T1  \
# 0  0.587693  0.561520  0.627496  0.627655  0.382482  0.260946  0.075933
# 1  0.645071  0.570706  0.557977  0.404167  0.322476  0.249424  0.087463
# 2  0.753785  0.795189  0.739009  0.635563  0.446836  0.276993  0.095515
# 3  0.648529  0.697784  0.671400  0.441939  0.443510  0.263333  0.064771
# 4  0.550273  0.556940  0.460278  0.414904  0.350851  0.259555  0.148328
#
#          T0
# 0  0.198708
# 1  0.205547
# 2  0.203885
# 3  0.203329
# 4  0.200369
#  Saved to sheet 'N_P4_logFC' in C:\Users\Barba\Desktop\N_combined.xlsx

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

# --- Gompertz model function ---
def gompertz_model(t, A, u, l):
    return A * np.exp(-np.exp(((u * np.e) / A) * (l - t) + 1))

# --- Timepoint mapping ---
time_mapping = {
    "T0": 0, "T1": 24, "T2": 45, "T3": 66,
    "T4": 93, "T5": 116, "T6": 142, "T7": 165
}
sorted_time_labels = sorted(time_mapping, key=lambda x: time_mapping[x])
x_data = np.array([time_mapping[t] for t in sorted_time_labels])

# --- Desktop paths ---
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")
conditions = ['C1', 'C2', 'N']

for condition in conditions:
    file_path = os.path.join(desktop_path, f"{condition}_combined.xlsx")
    if not os.path.exists(file_path):
        print(f"❌ File not found: {file_path}")
        continue

    excel_file = pd.ExcelFile(file_path, engine='openpyxl')
    logfc_sheets = [s for s in excel_file.sheet_names if s.endswith("_logFC")]

    for sheet in logfc_sheets:
        try:
            df = excel_file.parse(sheet)
            df = df[sorted_time_labels].dropna()
        except Exception as e:
            print(f"⚠️ Skipping sheet {sheet}: {e}")
            continue

        # Set up plot
        fig, axs = plt.subplots(8, 12, figsize=(24, 16))
        axs = axs.flatten()
        fit_results = []

        for i, (well_id, row) in enumerate(df.iterrows()):
            y_data = row.values.astype(float)

            try:
                popt, pcov = curve_fit(
                    gompertz_model, x_data, y_data,
                    p0=(2.0, 0.03, 5),
                    bounds=(0, [5, 0.2, 200])
                )
                y_fit = gompertz_model(x_data, *popt)
                r2 = r2_score(y_data, y_fit)
            except Exception:
                popt = [np.nan, np.nan, np.nan]
                y_fit = np.full_like(x_data, np.nan)
                r2 = np.nan

            fit_results.append({
                "Well": well_id,
                "Carrying_capacity (A)": popt[0],
                "Growth_rate (u)": popt[1],
                "Lag_time (λ)": popt[2],
                "R2": r2
            })

            # Plot individual well
            if i < len(axs):
                axs[i].plot(x_data, y_data, 'o', markersize=3)
                axs[i].plot(x_data, y_fit, '-', color='orange')
                axs[i].set_title(well_id, fontsize=6)
                axs[i].set_xlim(0, 170)
                axs[i].set_ylim(0, 3)
                axs[i].tick_params(axis='both', labelsize=5)

        # Remove unused subplots
        for j in range(i+1, len(axs)):
            fig.delaxes(axs[j])

        # Save plot
        plate_name = sheet.replace("_logFC", "")
        plot_filename = f"{plate_name}_gompertz_plot.png"
        plot_path = os.path.join(desktop_path, plot_filename)
        fig.tight_layout()
        fig.savefig(plot_path, dpi=300)
        plt.close(fig)

        # Save fit results to CSV
        fit_df = pd.DataFrame(fit_results)
        csv_filename = f"{plate_name}_Gompertz_fit.csv"
        csv_path = os.path.join(desktop_path, csv_filename)
        fit_df.to_csv(csv_path, index=False)

        print(f"✅ Processed {sheet} — Plot saved to {plot_filename}, CSV saved to {csv_filename}")
# Out:
# ✅ Processed C1_P1_logFC — Plot saved to C1_P1_gompertz_plot.png, CSV saved to C1_P1_Gompertz_fit.csv
# ✅ Processed C1_P2_logFC — Plot saved to C1_P2_gompertz_plot.png, CSV saved to C1_P2_Gompertz_fit.csv
# ✅ Processed C1_P3_logFC — Plot saved to C1_P3_gompertz_plot.png, CSV saved to C1_P3_Gompertz_fit.csv
# ✅ Processed C1_P4_logFC — Plot saved to C1_P4_gompertz_plot.png, CSV saved to C1_P4_Gompertz_fit.csv
# ✅ Processed C2_P1_logFC — Plot saved to C2_P1_gompertz_plot.png, CSV saved to C2_P1_Gompertz_fit.csv
# ✅ Processed C2_P2_logFC — Plot saved to C2_P2_gompertz_plot.png, CSV saved to C2_P2_Gompertz_fit.csv
# ✅ Processed C2_P3_logFC — Plot saved to C2_P3_gompertz_plot.png, CSV saved to C2_P3_Gompertz_fit.csv
# ✅ Processed C2_P4_logFC — Plot saved to C2_P4_gompertz_plot.png, CSV saved to C2_P4_Gompertz_fit.csv
# ✅ Processed N_P1_logFC — Plot saved to N_P1_gompertz_plot.png, CSV saved to N_P1_Gompertz_fit.csv
# ✅ Processed N_P2_logFC — Plot saved to N_P2_gompertz_plot.png, CSV saved to N_P2_Gompertz_fit.csv
# ✅ Processed N_P3_logFC — Plot saved to N_P3_gompertz_plot.png, CSV saved to N_P3_Gompertz_fit.csv
# C:\Users\Barba\AppData\Local\Temp\ipykernel_24744\3614863240.py:10: RuntimeWarning: overflow encountered in exp
#   return A * np.exp(-np.exp(((u * np.e) / A) * (l - t) + 1))
# ✅ Processed N_P4_logFC — Plot saved to N_P4_gompertz_plot.png, CSV saved to N_P4_Gompertz_fit.csv

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

# --- Gompertz model function ---
def gompertz_model(t, A, u, l):
    return A * np.exp(-np.exp(((u * np.e) / A) * (l - t) + 1))

# --- Timepoint mapping ---
time_mapping = {
    "T0": 0, "T1": 24, "T2": 45, "T3": 66,
    "T4": 93, "T5": 116, "T6": 142, "T7": 165
}
sorted_time_labels = sorted(time_mapping, key=lambda x: time_mapping[x])
x_data = np.array([time_mapping[t] for t in sorted_time_labels])

# --- Desktop path ---
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")
conditions = ['C1', 'C2', 'N']

# Process each condition
for condition in conditions:
    file_path = os.path.join(desktop_path, f"{condition}_combined.xlsx")
    if not os.path.exists(file_path):
        print(f"❌ File not found: {file_path}")
        continue

    excel_file = pd.ExcelFile(file_path, engine='openpyxl')
    logfc_sheets = [s for s in excel_file.sheet_names if s.endswith("_logFC")]

    combined_df = []
    for sheet in logfc_sheets:
        try:
            df = excel_file.parse(sheet)
            df = df[sorted_time_labels].dropna()
            df['Well'] = df.index
            combined_df.append(df)
        except Exception as e:
            print(f"⚠️ Skipping sheet {sheet}: {e}")

    if not combined_df:
        continue

    # Average across plates for this condition
    merged_df = pd.concat(combined_df).groupby("Well").mean()
    merged_df = merged_df[sorted_time_labels]

    # Set up plot
    fig, axs = plt.subplots(8, 12, figsize=(24, 16))
    axs = axs.flatten()
    fit_results = []

    for i, (well_id, row) in enumerate(merged_df.iterrows()):
        y_data = row.values.astype(float)

        try:
            popt, pcov = curve_fit(
                gompertz_model, x_data, y_data,
                p0=(2.0, 0.03, 5),
                bounds=(0, [5, 0.2, 200])
            )
            y_fit = gompertz_model(x_data, *popt)
            r2 = r2_score(y_data, y_fit)
        except Exception:
            popt = [np.nan, np.nan, np.nan]
            y_fit = np.full_like(x_data, np.nan)
            r2 = np.nan

        fit_results.append({
            "Well": well_id,
            "Carrying_capacity (A)": popt[0],
            "Growth_rate (u)": popt[1],
            "Lag_time (λ)": popt[2],
            "R2": r2
        })

        if i < len(axs):
            axs[i].plot(x_data, y_data, 'o', markersize=3)
            axs[i].plot(x_data, y_fit, '-', color='orange')
            axs[i].set_title(well_id, fontsize=6)
            axs[i].set_xlim(0, 170)
            axs[i].set_ylim(0, 3)
            axs[i].tick_params(axis='both', labelsize=5)

    for j in range(i+1, len(axs)):
        fig.delaxes(axs[j])

    # Save outputs
    plot_filename = f"{condition}_Average_gompertz_plot.png"
    csv_filename = f"{condition}_Average_Gompertz_fit.csv"

    fig.tight_layout()
    fig.savefig(os.path.join(desktop_path, plot_filename), dpi=300)
    plt.close(fig)

    pd.DataFrame(fit_results).to_csv(os.path.join(desktop_path, csv_filename), index=False)

    print(f"✅ Averaged and processed {condition} — Plot saved to {plot_filename}, CSV saved to {csv_filename}")
# Out:
# ✅ Averaged and processed C1 — Plot saved to C1_Average_gompertz_plot.png, CSV saved to C1_Average_Gompertz_fit.csv
# ✅ Averaged and processed C2 — Plot saved to C2_Average_gompertz_plot.png, CSV saved to C2_Average_Gompertz_fit.csv
# C:\Users\Barba\anaconda3\Lib\site-packages\numpy\core\numeric.py:407: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(res, fill_value, casting='unsafe')
# ✅ Averaged and processed N — Plot saved to N_Average_gompertz_plot.png, CSV saved to N_Average_Gompertz_fit.csv
